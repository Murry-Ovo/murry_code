# %%
## importing 2 dataframes to use for the histogram exercise

import pandas as pd

## replace with the locations you have saved the code to 
test_data_sales1 = pd.read_csv(r"C:\Users\andrew.morris\Documents\GitHub\murry_code\Codecademy Lesson Notes\test data\06b_test_data_histograms_sales1.csv") 
test_data_sales2 = pd.read_csv(r"C:\Users\andrew.morris\Documents\GitHub\murry_code\Codecademy Lesson Notes\test data\06b_test_data_histograms_sales2.csv") 

# print(test_data_sales1.head())
# print(test_data_sales2.head())

from matplotlib import pyplot as plt
import pandas as pd

sales_times = test_data_sales1.time_as_number
# print(sales_times.head())

plt.hist(sales_times, bins=20)

# plt.show()
# Out:
# (array([13., 21., 19., 16., 21., 18., 18., 13., 18., 20., 22., 21., 21.,
#         13., 15., 22., 23., 20., 16., 21.]),
#  array([ 8.    ,  8.6985,  9.397 , 10.0955, 10.794 , 11.4925, 12.191 ,
#         12.8895, 13.588 , 14.2865, 14.985 , 15.6835, 16.382 , 17.0805,
#         17.779 , 18.4775, 19.176 , 19.8745, 20.573 , 21.2715, 21.97  ]),
#  <a list of 20 Patch objects>)

# %%
## This code will run a SQL script against Big Query and export the results as a CSV to specified location

import pandas as pd
from datetime import datetime as dt

#######################
### INPUT VARIABLES ###
#######################


## sql query to run, paste between the multi row quotes
sql_code = """
SELECT *
FROM `boost-operations.Events.tbl_Non_Payers_And_Events`
"""

non_payers_and_events_df = pd.read_gbq(sql_code,
                 project_id = 'data-science-retail',
                 dialect = 'standard')

non_payers_and_events_df.head(20)
# Out:
# Downloading: 100%|██████████| 3449005/3449005 [15:06<00:00, 3806.50rows/s]
#    Snapshot_Date Meter_Point_No Account_No Last_Account_Vend_Date  \
# 0     2020-09-21     1000100910    7065422             2019-11-19
# 1     2020-09-21     1000100910    7065422             2019-11-19
# 2     2020-09-21     1000100910    7065422             2019-11-19
# 3     2020-09-21     1000100910    7065422             2019-11-19
# 4     2020-09-21     1000100910    7065422             2019-11-19
# 5     2020-09-21     1000100910    7065422             2019-11-19
# 6     2020-09-21     1000100910    7065422             2019-11-19
# 7     2020-09-21     1000100910    7065422             2019-11-19
# 8     2020-09-21     1000100910    7065422             2019-11-19
# 9     2020-09-21     1000100910    7065422             2019-11-19
# 10    2020-09-21     1000100910    7065422             2019-11-19
# 11    2020-09-21     1000100910    7065422             2019-11-19
# 12    2020-09-21     1000100910    7065422             2019-11-19
# 13    2020-09-21     1000100910    7065422             2019-11-19
# 14    2020-09-21     1000100910    7065422             2019-11-19
# 15    2020-09-21     1000100910    7065422             2019-11-19
# 16    2020-09-21     1000100910    7065422             2019-11-19
# 17    2020-09-21     1000100910    7065422             2019-11-19
# 18    2020-09-21     1000100910    7065422             2019-11-19
# 19    2020-09-21     1000100910    7065422             2019-11-19
#
#    Last_MPxN_Vend_Date Non_Payer_Day_Zero Non_Payer_Bracket  \
# 0           2019-11-19         2019-11-19          90+ Days
# 1           2019-11-19         2019-11-19          90+ Days
# 2           2019-11-19         2019-11-19          90+ Days
# 3           2019-11-19         2019-11-19          90+ Days
# 4           2019-11-19         2019-11-19          90+ Days
# 5           2019-11-19         2019-11-19          90+ Days
# 6           2019-11-19         2019-11-19          90+ Days
# 7           2019-11-19         2019-11-19          90+ Days
# 8           2019-11-19         2019-11-19          90+ Days
# 9           2019-11-19         2019-11-19          90+ Days
# 10          2019-11-19         2019-11-19          90+ Days
# 11          2019-11-19         2019-11-19          90+ Days
# 12          2019-11-19         2019-11-19          90+ Days
# 13          2019-11-19         2019-11-19          90+ Days
# 14          2019-11-19         2019-11-19          90+ Days
# 15          2019-11-19         2019-11-19          90+ Days
# 16          2019-11-19         2019-11-19          90+ Days
# 17          2019-11-19         2019-11-19          90+ Days
# 18          2019-11-19         2019-11-19          90+ Days
# 19          2019-11-19         2019-11-19          90+ Days
#
#    Meter_Type_Category PAYG_Proposition Root_Cause  \
# 0               SMETS2              BOL     SMETS2
# 1               SMETS2              BOL     SMETS2
# 2               SMETS2              BOL     SMETS2
# 3               SMETS2              BOL     SMETS2
# 4               SMETS2              BOL     SMETS2
# 5               SMETS2              BOL     SMETS2
# 6               SMETS2              BOL     SMETS2
# 7               SMETS2              BOL     SMETS2
# 8               SMETS2              BOL     SMETS2
# 9               SMETS2              BOL     SMETS2
# 10              SMETS2              BOL     SMETS2
# 11              SMETS2              BOL     SMETS2
# 12              SMETS2              BOL     SMETS2
# 13              SMETS2              BOL     SMETS2
# 14              SMETS2              BOL     SMETS2
# 15              SMETS2              BOL     SMETS2
# 16              SMETS2              BOL     SMETS2
# 17              SMETS2              BOL     SMETS2
# 18              SMETS2              BOL     SMETS2
# 19              SMETS2              BOL     SMETS2
#
#                                      Event  Event_Category Event_Date  \
# 0       COS Gain - Ovo Liability From Date        COS Gain 2019-01-12
# 1                         Top Up - Quantum          Top Up 2019-01-15
# 2                         Top Up - Quantum          Top Up 2019-01-22
# 3                         Top Up - Quantum          Top Up 2019-01-28
# 4   COS Gain - EE Industry Registered Date        COS Gain 2019-01-30
# 5                         Top Up - Quantum          Top Up 2019-02-03
# 6                         Top Up - Quantum          Top Up 2019-02-10
# 7                         Top Up - Quantum          Top Up 2019-02-20
# 8                         Top Up - Quantum          Top Up 2019-03-02
# 9                         Top Up - Quantum          Top Up 2019-03-17
# 10                        Top Up - Quantum          Top Up 2019-03-18
# 11                        Top Up - Quantum          Top Up 2019-04-01
# 12                Trad PAYG Meter Exchange  Meter Exchange 2019-04-02
# 13                        Top Up - Quantum          Top Up 2019-04-02
# 14                        Top Up - Quantum          Top Up 2019-04-15
# 15                        Top Up - Quantum          Top Up 2019-05-01
# 16                        Top Up - Quantum          Top Up 2019-05-08
# 17                        Top Up - Quantum          Top Up 2019-05-17
# 18                        Top Up - Quantum          Top Up 2019-05-24
# 19                        Top Up - Quantum          Top Up 2019-06-01
#
#     Event_To_NP_Day_Zero  Top_Up_On_Day_Zero  Has_Nerver_Paid
# 0                    311               False            False
# 1                    308               False            False
# 2                    301               False            False
# 3                    295               False            False
# 4                    293               False            False
# 5                    289               False            False
# 6                    282               False            False
# 7                    272               False            False
# 8                    262               False            False
# 9                    247               False            False
# 10                   246               False            False
# 11                   232               False            False
# 12                   231               False            False
# 13                   231               False            False
# 14                   218               False            False
# 15                   202               False            False
# 16                   195               False            False
# 17                   186               False            False
# 18                   179               False            False
# 19                   171               False            False
